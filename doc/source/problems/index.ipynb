# %% [raw]
# .. _nb_problems:

# %% [markdown]
# ## Test Problems
#
# Some problems copied from https://www.sfu.ca/~ssurjano/

# %% [markdown]
# ### Single-Objective

# %% [markdown]
# |Problem|Description|
# |-|-|
# |[Ackley](ackley.ipynb)||

# %% [markdown]
# ### Multi-Objective

# %% [markdown]
# |Problem|Description|
# |-|-|
# |[ZDT](zdt.ipynb)||

# %% [markdown]
# ### Many-Objective

# %% [markdown]
# |Problem|Description|
# |-|-|
# |[Ackley](ackley.ipynb)||
