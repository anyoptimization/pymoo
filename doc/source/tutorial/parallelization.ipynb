# %% [raw]
# .. _nb_parallelization:

# %% [markdown]
# ## Parallelization

# %% [markdown]
# By default whole population is evaluation in numpy array.
#
# However, elementwise_evaluation might be necessary.
#
# then paralleliation makes sense.
#
# i) vectorized through numpy
#
# ii) default
#
# iii) threads
#
# iv) dask

# %% [markdown]
# ### Vectorized through NumPy

# %% [markdown]
# ### Elementwise and Serialized

# %%
import numpy as np
import time
from pymoo.model.problem import Problem


class MyProblem(Problem):

    def __init__(self, **kwargs):
        super().__init__(n_var=2, n_obj=1, elementwise_evaluation=True, **kwargs)

    def _evaluate(self, x, out, *args, **kwargs):
        time.sleep(1)
        out["F"] = x.sum()

problem = MyProblem()
X = np.random.random((10,2))

# %%
problem.parallelization = None

# %%
# %time F = problem.evaluate(X)
# Out:
# CPU times: user 2.57 ms, sys: 1.77 ms, total: 4.34 ms
# Wall time: 10 s

# %% [markdown]
# ### Multiple Threads
#
# Uses multiprocess default in python
#
# default n-1 threads, but can be changed

# %%
problem.parallelization = "threads"

# %%
# %time F = problem.evaluate(X)
# Out:
# CPU times: user 23 ms, sys: 31.6 ms, total: 54.6 ms
# Wall time: 2.11 s

# %% [markdown]
# ### Dask

# %%
from dask.distributed import Client, client, LocalCluster
import numpy as np

from pymoo.model.problem import Problem

local = False

if local:
    cluster = LocalCluster(dashboard_address=":9300")
    client = Client(cluster)
else:
    client = Client(address="localhost:9000")
    #client = Client(address="host-94108.dhcp.egr.msu.edu:8786")

    
def task(x):
        return np.linalg.inv(x.reshape((1000,1000))).sum()

class MyProblem(Problem):

    def __init__(self, **kwargs):
        super().__init__(n_var=1000000, n_obj=1, elementwise_evaluation=False, **kwargs)

    def _evaluate(self, X, out, *args, **kwargs):
        jobs = client.map(task, X)
        out["F"] = np.row_stack([job.result() for job in jobs])


X = np.random.random((100, 1000000))
# %time F = MyProblem().evaluate(X)



class MyProblem(Problem):

    def __init__(self, **kwargs):
        super().__init__(n_var=1000000, n_obj=1, elementwise_evaluation=False, **kwargs)

    def _evaluate(self, X, out, *args, **kwargs):
        out["F"] = np.row_stack([task(x) for x in X])
        
# %time F = MyProblem().evaluate(X)
# Out:
# /Users/blankjul/anaconda3/lib/python3.7/site-packages/distributed/worker.py:2791: UserWarning: Large object of size 8.00 MB detected in task graph:
#   (array([0.24855179, 0.44244268, 0.52615791, ..., 0 ...  0.24339124]),)
# Consider scattering large objects ahead of time
# with client.scatter to reduce scheduler burden and
# keep data on workers
#
#     future = client.submit(func, big_data)    # bad
#
#     big_future = client.scatter(big_data)     # good
#     future = client.submit(func, big_future)  # good
#   % (format_bytes(len(b)), s))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/workspace/pymoo/pymoo/model/problem.py in evaluate(self, X, return_values_of, return_as_dictionary, *args, **kwargs)
#     201             out = self._evaluate_elementwise(X, calc_gradient, *args, **kwargs)
#     202         else:
# --> 203             out = self._evaluate_batch(X, calc_gradient, *args, **kwargs)
#     204
#     205         calc_gradient_of = [key for key, val in out.items()
#
# ~/workspace/pymoo/pymoo/model/problem.py in _evaluate_batch(self, X, calc_gradient, *args, **kwargs)
#     265             out["__autograd__"], _ = run_and_trace(self._evaluate, X, *[out])
#     266         else:
# --> 267             self._evaluate(X, out, *args, **kwargs)
#     268         at_least2d(out)
#     269
#
# <ipython-input-17-60bedac587f8> in _evaluate(self, X, out, *args, **kwargs)
#      24     def _evaluate(self, X, out, *args, **kwargs):
#      25         jobs = client.map(task, X)
# ---> 26         out["F"] = np.row_stack([job.result() for job in jobs])
#      27
#      28
#
# <ipython-input-17-60bedac587f8> in <listcomp>(.0)
#      24     def _evaluate(self, X, out, *args, **kwargs):
#      25         jobs = client.map(task, X)
# ---> 26         out["F"] = np.row_stack([job.result() for job in jobs])
#      27
#      28
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in result(self, timeout)
#     192         # shorten error traceback
#     193         result = self.client.sync(self._result, callback_timeout=timeout,
# --> 194                                   raiseit=False)
#     195         if self.status == 'error':
#     196             six.reraise(*result)
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/client.py in sync(self, func, *args, **kwargs)
#     674             return future
#     675         else:
# --> 676             return sync(self.loop, func, *args, **kwargs)
#     677
#     678     def __repr__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/distributed/utils.py in sync(loop, func, *args, **kwargs)
#     273     else:
#     274         while not e.is_set():
# --> 275             e.wait(10)
#     276     if error[0]:
#     277         six.reraise(*error[0])
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/anaconda3/lib/python3.7/threading.py in wait(self, timeout)
#     298             else:
#     299                 if timeout > 0:
# --> 300                     gotit = waiter.acquire(True, timeout)
#     301                 else:
#     302                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# CPU times: user 30.4 s, sys: 3.2 s, total: 33.6 s
# Wall time: 8.81 s
# tornado.application - ERROR - Exception in callback <bound method Client._heartbeat of <Client: scheduler='tcp://35.9.132.172:8786' processes=40 cores=40>>
# Traceback (most recent call last):
#   File "/Users/blankjul/anaconda3/lib/python3.7/site-packages/tornado/ioloop.py", line 907, in _run
#     return self.callback()
#   File "/Users/blankjul/anaconda3/lib/python3.7/site-packages/distributed/client.py", line 931, in _heartbeat
#     self.scheduler_comm.send({'op': 'heartbeat-client'})
#   File "/Users/blankjul/anaconda3/lib/python3.7/site-packages/distributed/batched.py", line 117, in send
#     raise CommClosedError
# distributed.comm.core.CommClosedError
# distributed.batched - INFO - Batched Comm Closed: in <closed TCP>: BrokenPipeError: [Errno 32] Broken pipe
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63487 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54946 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54947 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:53891 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:56219 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53900 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55938 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:53893 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53903 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53904 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:56234 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55953 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55957 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55960 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55959 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55958 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55961 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55962 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53906 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53907 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55160 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55161 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55163 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55159 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55157 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55165 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55686 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55688 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55687 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54920 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54921 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54922 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51800 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51803 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54933 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63719 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51804 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55190 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63722 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51806 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51807 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55193 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54939 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63723 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55194 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63725 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63726 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55196 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55197 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54171 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54181 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54182 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54184 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63956 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54185 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63960 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63958 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55436 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55433 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55442 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55450 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55440 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55439 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55437 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55438 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55434 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55445 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55443 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55444 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55451 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55448 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55441 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55435 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55446 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55449 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55447 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55454 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55453 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55452 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55456 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55455 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55457 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55458 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55164 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55162 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55158 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55166 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55167 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55183 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52074 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63989 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52075 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52078 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52076 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52077 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52080 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52081 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52082 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52084 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52083 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52086 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52085 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52087 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52088 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63992 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52089 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52090 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52091 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55473 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63993 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55474 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63995 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:63996 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55476 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:55477 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54405 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54415 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54425 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54426 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54428 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54429 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55459 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55461 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52340 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52343 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:55463 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52344 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64251 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52346 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64254 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52347 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64255 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64257 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54660 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://127.0.0.1:54661 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54683 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54696 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54701 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54702 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54704 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54705 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54703 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52613 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52614 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52616 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64554 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52617 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64555 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64557 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64558 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54940 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:54943 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52856 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52859 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52860 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64810 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52862 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:52863 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64811 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64813 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:64814 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53110 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53113 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53114 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65072 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53116 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53117 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65073 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65075 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65076 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53366 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53380 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53385 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65305 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53389 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53388 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53387 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53390 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53392 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53391 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53393 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53394 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53395 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53396 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53397 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53398 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53399 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65308 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53400 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65309 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65311 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:65312 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49161 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49162 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49163 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49170 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49166 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49169 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49173 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49165 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49164 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49168 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49172 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49167 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49174 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49171 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49175 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49176 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49182 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49179 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49180 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49177 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49181 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49178 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49183 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53634 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53637 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53638 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53640 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49201 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53641 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49202 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49204 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49205 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53868 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53866 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:53869 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49440 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49441 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49443 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49442 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49445 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49448 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49444 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49449 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49447 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49451 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49450 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49452 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49454 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49455 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49456 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49457 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49458 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49459 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49461 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49462 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49715 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49718 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49720 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49722 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49723 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49974 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49977 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49978 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49980 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:49981 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50201 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50239 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50240 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50242 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50243 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50484 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50487 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50488 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50490 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50491 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50766 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50772 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50773 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50774 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50775 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50776 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50777 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50779 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50778 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50781 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50782 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50780 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50783 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50784 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50785 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50787 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50788 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50789 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50790 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:50791 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51034 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51036 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51039 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51040 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51042 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51043 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51299 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51300 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51302 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51303 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51547 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51548 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51550 remote=tcp://localhost:9000>
# distributed.comm.tcp - WARNING - Closing dangling stream in <TCP local=tcp://[::1]:51551 remote=tcp://localhost:9000>
