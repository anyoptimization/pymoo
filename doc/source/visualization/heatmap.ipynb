# %% [raw]
# .. _nb_heat:

# %% [markdown]
# ## Heatmap

# %% [markdown]
# For getting in idea of the distribution of values heatmaps can be used.
#
# Let us visualize some test data:

# %%
import numpy as np

np.random.seed(1234)
F = np.random.random((4, 6))

# %% [markdown]
# A simple heatmap can be created by:

# %%
from pymoo.analytics.visualization.heatmap import heatmap
heatmap().add(F).show()

# %% [raw]
# By default, larger values are represent with wight and smaller values with the coresponding color:

# %%
heatmap(bounds=[0,1]).add(np.ones((1, 6))).show()

# %% [markdown]
# This behaviour can be changed by setting reverse to False.

# %%
heatmap(bounds=[0,1],reverse=False).add(np.ones((1, 6))).show()

# %% [markdown]
# The plot can be further customized by supplying a title, labels, and by using the plotting directives from matplotlib. Also, the colors can be changed:

# %%
plot = heatmap(title=("Optimization", {'pad': 15}),
               cmap="Oranges_r",
               y_labels=["Solution A", "Solution B", "Solution C", "Solution D"],
               labels=["profit", "cost", "sustainability", "environment", "satisfaction", "time"])
plot.add(F)
plot.show()

# %% [markdown]
# Moreover, the values can be sorted lexicographically by a objective(s) - default the selected objective is insert in position 0 of the range of objectives. Also, the boundaries can be changed. Otherwise, it is scaled according to the smallest and largest values supplied.

# %%
F = np.random.random((30, 6))

plot = heatmap(figsize=(10,30),
               bound=[0,1],
               order_by_objectives=0,
               y_labels=None,
               labels=["profit", "cost", "sustainability", "environment", "satisfaction", "time"],
               cmap="Greens_r")

plot.add(F, aspect=0.2)
plot.show()

# %% [markdown]
# ### API

# %% [raw]
# .. autofunction:: pymoo.analytics.visualization.heatmap.heatmap
#     :noindex:
