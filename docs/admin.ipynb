# %% [markdown]
# ## Documentation

# %% [markdown]
# ### HTML

# %%
# %%bash
#
# make html
# find build -type f -name '*.ipynb' -delete
# Out:
# UsageError: %%bash is a cell magic, but the cell body is empty.

# %% [markdown]
# ### Clear

# %%
# %%bash
# rm -rf build/html/*

# %%
# %%bash
# eval "$(conda shell.bash hook)"
# conda activate /home/jupyter-blankjul/anaconda3/envs/pypi
# python -m ipykernel install --user --name=pipy
# Out:
# Installed kernelspec pipy in /home/jupyter-blankjul/.local/share/jupyter/kernels/pipy

# %% [markdown]
# ## Notebooks

# %% [markdown]
# ### Serve

# %%
# %%bash
#
# python3 -m http.server --directory  build/html

# %% [markdown]
# ### Clear

# %%
# %%bash
#
# jupyter nbconvert --ClearOutputPreprocessor.enabled=True --inplace  source/algorithms/moo/nsga2.ipynb
# Out:
# [NbConvertApp] Converting notebook source/algorithms/moo/nsga2.ipynb to notebook
# [NbConvertApp] Writing 5857 bytes to source/algorithms/moo/nsga2.ipynb

# %%
# %%bash
#
# for file in $(find source -name '*.ipynb');
# do
#     echo $file
#     python ./clear.py  $file
# done;
# Out:
# source/operators/sampling.ipynb
# source/operators/selection.ipynb
# source/operators/mutation.ipynb
# source/operators/crossover.ipynb
# source/operators/index.ipynb
# source/operators/repair.ipynb
# source/versions.ipynb
# source/getting_started/part_2.ipynb
# source/getting_started/part_3.ipynb
# source/getting_started/preface.ipynb
# source/getting_started/part_1.ipynb
# source/getting_started/source_code.ipynb
# source/getting_started/part_4.ipynb
# source/getting_started/part_5.ipynb
# source/getting_started/index.ipynb
# source/problems/dynamic/df.ipynb
# source/problems/test_problems.ipynb
# source/problems/parallelization.ipynb
# source/problems/multi/sym_part.ipynb
# source/problems/multi/welded_beam.ipynb
# source/problems/multi/tnk.ipynb
# source/problems/multi/omni_test.ipynb
# source/problems/multi/truss2d.ipynb
# source/problems/multi/osy.ipynb
# source/problems/multi/bnh.ipynb
# source/problems/multi/zdt.ipynb
# source/problems/constrained/dascmop.ipynb
# source/problems/constrained/mw.ipynb
# source/problems/constrained/modact.ipynb
# source/problems/definition.ipynb
# source/problems/many/wfg.ipynb
# source/problems/many/dtlz.ipynb
# source/problems/index.ipynb
# source/problems/single/griewank.ipynb
# source/problems/single/rastrigin.ipynb
# source/problems/single/rosenbrock.ipynb
# source/problems/single/zakharov.ipynb
# source/problems/single/ackley.ipynb
# source/.ipynb_checkpoints/versions-checkpoint.ipynb
# source/case_studies/index.ipynb
# source/case_studies/subset_selection.ipynb
# source/case_studies/portfolio_allocation.ipynb
# source/constraints/index.ipynb
# source/constraints/repair.ipynb
# source/constraints/feas_first.ipynb
# source/constraints/as_penalty.ipynb
# source/constraints/eps.ipynb
# source/constraints/problem.ipynb
# source/constraints/as_obj.ipynb
# source/gradients/index.ipynb
# source/visualization/radviz.ipynb
# source/visualization/index.ipynb
# source/visualization/pcp.ipynb
# source/visualization/radar.ipynb
# source/visualization/petal.ipynb
# source/visualization/video.ipynb
# source/visualization/scatter.ipynb
# source/visualization/star.ipynb
# source/visualization/heatmap.ipynb
# source/installation.ipynb
# source/interface/display.ipynb
# source/interface/problem.ipynb
# source/interface/minimize.ipynb
# source/interface/algorithm.ipynb
# source/interface/result.ipynb
# source/interface/callback.ipynb
# source/interface/index.ipynb
# source/interface/termination.ipynb
# source/customization/initialization.ipynb
# source/customization/discrete.ipynb
# source/customization/subset.ipynb
# source/customization/custom.ipynb
# source/customization/binary.ipynb
# source/customization/permutation.ipynb
# source/customization/mixed.ipynb
# source/mcdm/index.ipynb
# source/contribute.ipynb
# source/misc/kktpm.ipynb
# source/misc/decomposition.ipynb
# source/misc/indicators.ipynb
# source/misc/convergence.ipynb
# source/misc/index.ipynb
# source/misc/checkpoint.ipynb
# source/misc/reference_directions.ipynb
# source/algorithms/usage.ipynb
# source/algorithms/initialization.ipynb
# source/algorithms/moo/ctaea.ipynb
# source/algorithms/moo/rvea.ipynb
# source/algorithms/moo/moead.ipynb
# source/algorithms/moo/nsga3.ipynb
# source/algorithms/moo/.ipynb_checkpoints/nsga2-checkpoint.ipynb
# source/algorithms/moo/age.ipynb
# source/algorithms/moo/dnsga2.ipynb
# source/algorithms/moo/rnsga3.ipynb
# source/algorithms/moo/unsga3.ipynb
# source/algorithms/moo/sms.ipynb
# source/algorithms/moo/nsga2.ipynb
# source/algorithms/moo/age2.ipynb
# source/algorithms/moo/rnsga2.ipynb
# source/algorithms/list.ipynb
# source/algorithms/soo/sres.ipynb
# source/algorithms/soo/isres.ipynb
# source/algorithms/soo/es.ipynb
# source/algorithms/soo/pso.ipynb
# source/algorithms/soo/de.ipynb
# source/algorithms/soo/nelder.ipynb
# source/algorithms/soo/brkga.ipynb
# source/algorithms/soo/pattern.ipynb
# source/algorithms/soo/g3pcx.ipynb
# source/algorithms/soo/ga.ipynb
# source/algorithms/soo/cmaes.ipynb
# source/algorithms/hyperparameters.ipynb
# source/algorithms/index.ipynb
# source/faq.ipynb

# %% [markdown]
# ### Run

# %%
# %%bash
# eval "$(conda shell.bash hook)"
# conda activate /home/jupyter-blankjul/anaconda3/envs/pypi
#
# for file in $(find source -name '*.ipynb');
# do
#     jupyter nbconvert --execute --to notebook --inplace $file
# done;
# echo 'DONE'
# Out:
# [NbConvertApp] Converting notebook source/operators/sampling.ipynb to notebook
# [NbConvertApp] Writing 67406 bytes to source/operators/sampling.ipynb
# [NbConvertApp] Converting notebook source/operators/selection.ipynb to notebook
# [NbConvertApp] Writing 6309 bytes to source/operators/selection.ipynb
# [NbConvertApp] Converting notebook source/operators/mutation.ipynb to notebook
# [NbConvertApp] Writing 31028 bytes to source/operators/mutation.ipynb
# [NbConvertApp] Converting notebook source/operators/crossover.ipynb to notebook
# [NbConvertApp] Writing 71623 bytes to source/operators/crossover.ipynb
# [NbConvertApp] Converting notebook source/operators/index.ipynb to notebook
# [NbConvertApp] Writing 3469 bytes to source/operators/index.ipynb
# [NbConvertApp] Converting notebook source/operators/repair.ipynb to notebook
# [NbConvertApp] Writing 9443 bytes to source/operators/repair.ipynb
# [NbConvertApp] Converting notebook source/versions.ipynb to notebook
# [NbConvertApp] Writing 10463 bytes to source/versions.ipynb
# [NbConvertApp] Converting notebook source/getting_started/part_2.ipynb to notebook
# [NbConvertApp] Writing 49311 bytes to source/getting_started/part_2.ipynb
# [NbConvertApp] Converting notebook source/getting_started/part_3.ipynb to notebook
# [NbConvertApp] Writing 98096 bytes to source/getting_started/part_3.ipynb
# [NbConvertApp] Converting notebook source/getting_started/preface.ipynb to notebook
# [NbConvertApp] Writing 10225 bytes to source/getting_started/preface.ipynb
# [NbConvertApp] Converting notebook source/getting_started/part_1.ipynb to notebook
# [NbConvertApp] Writing 95914 bytes to source/getting_started/part_1.ipynb
# [NbConvertApp] Converting notebook source/getting_started/source_code.ipynb to notebook
# [NbConvertApp] Writing 24905 bytes to source/getting_started/source_code.ipynb
# [NbConvertApp] Converting notebook source/getting_started/part_4.ipynb to notebook
# [NbConvertApp] Writing 263440 bytes to source/getting_started/part_4.ipynb
# [NbConvertApp] Converting notebook source/getting_started/part_5.ipynb to notebook
# [NbConvertApp] Writing 3954 bytes to source/getting_started/part_5.ipynb
# [NbConvertApp] Converting notebook source/getting_started/index.ipynb to notebook
# [NbConvertApp] Writing 2814 bytes to source/getting_started/index.ipynb
# [NbConvertApp] Converting notebook source/problems/dynamic/df.ipynb to notebook
# [NbConvertApp] Writing 2812455 bytes to source/problems/dynamic/df.ipynb
# [NbConvertApp] Converting notebook source/problems/test_problems.ipynb to notebook
# [NbConvertApp] Writing 16036 bytes to source/problems/test_problems.ipynb
# [NbConvertApp] Converting notebook source/problems/parallelization.ipynb to notebook
# [NbConvertApp] Writing 17007 bytes to source/problems/parallelization.ipynb
# [NbConvertApp] Converting notebook source/problems/multi/sym_part.ipynb to notebook
# [NbConvertApp] Writing 47396 bytes to source/problems/multi/sym_part.ipynb
# [NbConvertApp] Converting notebook source/problems/multi/welded_beam.ipynb to notebook
# [NbConvertApp] Writing 18536 bytes to source/problems/multi/welded_beam.ipynb
# [NbConvertApp] Converting notebook source/problems/multi/tnk.ipynb to notebook
# [NbConvertApp] Writing 15651 bytes to source/problems/multi/tnk.ipynb
# [NbConvertApp] Converting notebook source/problems/multi/omni_test.ipynb to notebook
# [NbConvertApp] Writing 72781 bytes to source/problems/multi/omni_test.ipynb
# [NbConvertApp] Converting notebook source/problems/multi/truss2d.ipynb to notebook
# [NbConvertApp] Writing 43914 bytes to source/problems/multi/truss2d.ipynb
# [NbConvertApp] Converting notebook source/problems/multi/osy.ipynb to notebook
# [NbConvertApp] Writing 17722 bytes to source/problems/multi/osy.ipynb
# [NbConvertApp] Converting notebook source/problems/multi/bnh.ipynb to notebook
# [NbConvertApp] Writing 18241 bytes to source/problems/multi/bnh.ipynb
# [NbConvertApp] Converting notebook source/problems/multi/zdt.ipynb to notebook
# [NbConvertApp] Writing 112887 bytes to source/problems/multi/zdt.ipynb
# [NbConvertApp] Converting notebook source/problems/constrained/dascmop.ipynb to notebook
# [NbConvertApp] Writing 158256 bytes to source/problems/constrained/dascmop.ipynb
# [NbConvertApp] Converting notebook source/problems/constrained/mw.ipynb to notebook
# [NbConvertApp] Writing 340184 bytes to source/problems/constrained/mw.ipynb
# [NbConvertApp] Converting notebook source/problems/constrained/modact.ipynb to notebook
# Traceback (most recent call last):
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/traitlets/config/application.py", line 976, in launch_instance
#     app.start()
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 423, in start
#     self.convert_notebooks()
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 560, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 488, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 189, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 206, in from_file
#     return self.from_notebook_node(
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/notebook.py", line 35, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 146, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 335, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/preprocessors/base.py", line 47, in __call__
#     return self.preprocess(nb, resources)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/preprocessors/execute.py", line 89, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/preprocessors/execute.py", line 110, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/util.py", line 85, in wrapped
#     return just_run(coro(*args, **kwargs))
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/util.py", line 60, in just_run
#     return loop.run_until_complete(coro)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/asyncio/base_events.py", line 647, in run_until_complete
#     return future.result()
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/client.py", line 1025, in async_execute_cell
#     await self._check_raise_for_error(cell, cell_index, exec_reply)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/client.py", line 919, in _check_raise_for_error
#     raise CellExecutionError.from_cell_and_msg(cell, exec_reply_content)
# nbclient.exceptions.CellExecutionError: An error occurred while executing the following cell:
# ------------------
# from pymoo.problems.multi import MODAct
# from pymoo.util.plotting import plot
#
# problem = MODAct("cs3")
# plot(problem.pareto_front(), no_fill=True)
# ------------------
#
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/anaconda3/envs/pypi/lib/python3.9/site-packages/pymoo/problems/multi/modact.py:34, in MODAct.__init__(self, function, pf, **kwargs)
#      33 try:
# ---> 34     import modact.problems as pb
#      35 except:
#
# ModuleNotFoundError: No module named 'modact'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 from pymoo.problems.multi import MODAct
#       2 from pymoo.util.plotting import plot
# ----> 4 problem = MODAct("cs3")
#       5 plot(problem.pareto_front(), no_fill=True)
#
# File ~/anaconda3/envs/pypi/lib/python3.9/site-packages/pymoo/problems/multi/modact.py:36, in MODAct.__init__(self, function, pf, **kwargs)
#      34     import modact.problems as pb
#      35 except:
# ---> 36     raise Exception("Please install the modact library: https://github.com/epfl-lamd/modact")
#      38 if isinstance(function, pb.Problem):
#      39     self.fct = function
#
# Exception: Please install the modact library: https://github.com/epfl-lamd/modact
# Exception: Please install the modact library: https://github.com/epfl-lamd/modact
#
# [NbConvertApp] Converting notebook source/problems/definition.ipynb to notebook
# [NbConvertApp] Writing 12093 bytes to source/problems/definition.ipynb
# [NbConvertApp] Converting notebook source/problems/many/wfg.ipynb to notebook
# [NbConvertApp] Writing 1175 bytes to source/problems/many/wfg.ipynb
# [NbConvertApp] Converting notebook source/problems/many/dtlz.ipynb to notebook
# [NbConvertApp] Writing 475998 bytes to source/problems/many/dtlz.ipynb
# [NbConvertApp] Converting notebook source/problems/index.ipynb to notebook
# [NbConvertApp] Writing 2018 bytes to source/problems/index.ipynb
# [NbConvertApp] Converting notebook source/problems/single/griewank.ipynb to notebook
# [NbConvertApp] Writing 46758 bytes to source/problems/single/griewank.ipynb
# [NbConvertApp] Converting notebook source/problems/single/rastrigin.ipynb to notebook
# [NbConvertApp] Writing 556534 bytes to source/problems/single/rastrigin.ipynb
# [NbConvertApp] Converting notebook source/problems/single/rosenbrock.ipynb to notebook
# [NbConvertApp] Writing 240939 bytes to source/problems/single/rosenbrock.ipynb
# [NbConvertApp] Converting notebook source/problems/single/zakharov.ipynb to notebook
# [NbConvertApp] Writing 335202 bytes to source/problems/single/zakharov.ipynb
# [NbConvertApp] Converting notebook source/problems/single/ackley.ipynb to notebook
# [NbConvertApp] Writing 480613 bytes to source/problems/single/ackley.ipynb
# [NbConvertApp] Converting notebook source/.ipynb_checkpoints/versions-checkpoint.ipynb to notebook
# [NbConvertApp] Writing 8392 bytes to source/.ipynb_checkpoints/versions-checkpoint.ipynb
# [NbConvertApp] Converting notebook source/case_studies/index.ipynb to notebook
# [NbConvertApp] Writing 1371 bytes to source/case_studies/index.ipynb
# [NbConvertApp] Converting notebook source/case_studies/subset_selection.ipynb to notebook
# [NbConvertApp] Writing 14227 bytes to source/case_studies/subset_selection.ipynb
# [NbConvertApp] Converting notebook source/case_studies/portfolio_allocation.ipynb to notebook
# [NbConvertApp] Writing 78730 bytes to source/case_studies/portfolio_allocation.ipynb
# [NbConvertApp] Converting notebook source/constraints/index.ipynb to notebook
# [NbConvertApp] Writing 140436 bytes to source/constraints/index.ipynb
# [NbConvertApp] Converting notebook source/constraints/repair.ipynb to notebook
# [NbConvertApp] Writing 9681 bytes to source/constraints/repair.ipynb
# [NbConvertApp] Converting notebook source/constraints/feas_first.ipynb to notebook
# [NbConvertApp] Writing 3620 bytes to source/constraints/feas_first.ipynb
# [NbConvertApp] Converting notebook source/constraints/as_penalty.ipynb to notebook
# [NbConvertApp] Writing 6185 bytes to source/constraints/as_penalty.ipynb
# [NbConvertApp] Converting notebook source/constraints/eps.ipynb to notebook
# [NbConvertApp] Writing 3637 bytes to source/constraints/eps.ipynb
# [NbConvertApp] Converting notebook source/constraints/problem.ipynb to notebook
# [NbConvertApp] Writing 810 bytes to source/constraints/problem.ipynb
# [NbConvertApp] Converting notebook source/constraints/as_obj.ipynb to notebook
# [NbConvertApp] Writing 26782 bytes to source/constraints/as_obj.ipynb
# [NbConvertApp] Converting notebook source/gradients/index.ipynb to notebook
# [NbConvertApp] Writing 4089 bytes to source/gradients/index.ipynb
# [NbConvertApp] Converting notebook source/visualization/radviz.ipynb to notebook
# [NbConvertApp] Writing 60341 bytes to source/visualization/radviz.ipynb
# [NbConvertApp] Converting notebook source/visualization/index.ipynb to notebook
# [NbConvertApp] Writing 53875 bytes to source/visualization/index.ipynb
# [NbConvertApp] Converting notebook source/visualization/pcp.ipynb to notebook
# [NbConvertApp] Writing 433430 bytes to source/visualization/pcp.ipynb
# [NbConvertApp] Converting notebook source/visualization/radar.ipynb to notebook
# [NbConvertApp] Writing 98246 bytes to source/visualization/radar.ipynb
# [NbConvertApp] Converting notebook source/visualization/petal.ipynb to notebook
# [NbConvertApp] Writing 158581 bytes to source/visualization/petal.ipynb
# [NbConvertApp] Converting notebook source/visualization/video.ipynb to notebook
# [NbConvertApp] ERROR | Kernel died while waiting for execute reply.
# Traceback (most recent call last):
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/client.py", line 780, in _async_poll_for_reply
#     msg = await ensure_async(self.kc.shell_channel.get_msg(timeout=new_timeout))
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/util.py", line 97, in ensure_async
#     result = await obj
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/jupyter_client/channels.py", line 224, in get_msg
#     ready = await self.socket.poll(timeout)
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/client.py", line 1006, in async_execute_cell
#     exec_reply = await self.task_poll_for_reply
# asyncio.exceptions.CancelledError
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/bin/jupyter-nbconvert", line 8, in <module>
#     sys.exit(main())
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/jupyter_core/application.py", line 269, in launch_instance
#     return super().launch_instance(argv=argv, **kwargs)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/traitlets/config/application.py", line 976, in launch_instance
#     app.start()
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 423, in start
#     self.convert_notebooks()
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 597, in convert_notebooks
#     self.convert_single_notebook(notebook_filename)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 560, in convert_single_notebook
#     output, resources = self.export_single_notebook(
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/nbconvertapp.py", line 488, in export_single_notebook
#     output, resources = self.exporter.from_filename(
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 189, in from_filename
#     return self.from_file(f, resources=resources, **kw)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 206, in from_file
#     return self.from_notebook_node(
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/notebook.py", line 35, in from_notebook_node
#     nb_copy, resources = super().from_notebook_node(nb, resources, **kw)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 146, in from_notebook_node
#     nb_copy, resources = self._preprocess(nb_copy, resources)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/exporters/exporter.py", line 335, in _preprocess
#     nbc, resc = preprocessor(nbc, resc)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/preprocessors/base.py", line 47, in __call__
#     return self.preprocess(nb, resources)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/preprocessors/execute.py", line 89, in preprocess
#     self.preprocess_cell(cell, resources, index)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbconvert/preprocessors/execute.py", line 110, in preprocess_cell
#     cell = self.execute_cell(cell, index, store_history=True)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/util.py", line 85, in wrapped
#     return just_run(coro(*args, **kwargs))
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/util.py", line 60, in just_run
#     return loop.run_until_complete(coro)
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/asyncio/base_events.py", line 647, in run_until_complete
#     return future.result()
#   File "/home/jupyter-blankjul/anaconda3/envs/pypi/lib/python3.9/site-packages/nbclient/client.py", line 1010, in async_execute_cell
#     raise DeadKernelError("Kernel died")
# nbclient.exceptions.DeadKernelError: Kernel died
# [NbConvertApp] Converting notebook source/visualization/scatter.ipynb to notebook
# [NbConvertApp] Writing 140665 bytes to source/visualization/scatter.ipynb
# [NbConvertApp] Converting notebook source/visualization/star.ipynb to notebook
# [NbConvertApp] Writing 42429 bytes to source/visualization/star.ipynb
# [NbConvertApp] Converting notebook source/visualization/heatmap.ipynb to notebook
# [NbConvertApp] Writing 46010 bytes to source/visualization/heatmap.ipynb
# [NbConvertApp] Converting notebook source/installation.ipynb to notebook
# [NbConvertApp] Writing 6988 bytes to source/installation.ipynb
# [NbConvertApp] Converting notebook source/interface/display.ipynb to notebook
# [NbConvertApp] Writing 5609 bytes to source/interface/display.ipynb
# [NbConvertApp] Converting notebook source/interface/problem.ipynb to notebook
# [NbConvertApp] Writing 6004 bytes to source/interface/problem.ipynb
# [NbConvertApp] Converting notebook source/interface/minimize.ipynb to notebook
# [NbConvertApp] Writing 3730 bytes to source/interface/minimize.ipynb
# [NbConvertApp] Converting notebook source/interface/algorithm.ipynb to notebook
# [NbConvertApp] Writing 2068 bytes to source/interface/algorithm.ipynb
# [NbConvertApp] Converting notebook source/interface/result.ipynb to notebook
# [NbConvertApp] Writing 16720 bytes to source/interface/result.ipynb
# [NbConvertApp] Converting notebook source/interface/callback.ipynb to notebook
# [NbConvertApp] Writing 31792 bytes to source/interface/callback.ipynb
# [NbConvertApp] Converting notebook source/interface/index.ipynb to notebook
# [NbConvertApp] Writing 3885 bytes to source/interface/index.ipynb
# [NbConvertApp] Converting notebook source/interface/termination.ipynb to notebook
# [NbConvertApp] Writing 38654 bytes to source/interface/termination.ipynb
# [NbConvertApp] Converting notebook source/customization/initialization.ipynb to notebook
# [NbConvertApp] Writing 6607 bytes to source/customization/initialization.ipynb
# [NbConvertApp] Converting notebook source/customization/discrete.ipynb to notebook
# [NbConvertApp] Writing 13804 bytes to source/customization/discrete.ipynb
# [NbConvertApp] Converting notebook source/customization/subset.ipynb to notebook
# [NbConvertApp] Writing 14227 bytes to source/customization/subset.ipynb
# [NbConvertApp] Converting notebook source/customization/custom.ipynb to notebook
# [NbConvertApp] Writing 20376 bytes to source/customization/custom.ipynb
# [NbConvertApp] Converting notebook source/customization/binary.ipynb to notebook
# [NbConvertApp] Writing 3012 bytes to source/customization/binary.ipynb
# [NbConvertApp] Converting notebook source/customization/permutation.ipynb to notebook
# [NbConvertApp] Writing 85942 bytes to source/customization/permutation.ipynb
# [NbConvertApp] Converting notebook source/customization/mixed.ipynb to notebook
# [NbConvertApp] Writing 18558 bytes to source/customization/mixed.ipynb
# [NbConvertApp] Converting notebook source/mcdm/index.ipynb to notebook
# [NbConvertApp] Writing 115488 bytes to source/mcdm/index.ipynb
# [NbConvertApp] Converting notebook source/contribute.ipynb to notebook
# [NbConvertApp] Writing 2136 bytes to source/contribute.ipynb
# [NbConvertApp] Converting notebook source/misc/kktpm.ipynb to notebook
# [NbConvertApp] Writing 30209 bytes to source/misc/kktpm.ipynb
# [NbConvertApp] Converting notebook source/misc/decomposition.ipynb to notebook
# [NbConvertApp] Writing 96827 bytes to source/misc/decomposition.ipynb
# [NbConvertApp] Converting notebook source/misc/indicators.ipynb to notebook
# [NbConvertApp] Writing 23660 bytes to source/misc/indicators.ipynb
# [NbConvertApp] Converting notebook source/misc/convergence.ipynb to notebook
# [NbConvertApp] Writing 33453 bytes to source/misc/convergence.ipynb
# [NbConvertApp] Converting notebook source/misc/index.ipynb to notebook
# [NbConvertApp] Writing 1338 bytes to source/misc/index.ipynb
# [NbConvertApp] Converting notebook source/misc/checkpoint.ipynb to notebook
# [NbConvertApp] Writing 12332 bytes to source/misc/checkpoint.ipynb
# [NbConvertApp] Converting notebook source/misc/reference_directions.ipynb to notebook
# [NbConvertApp] Writing 688414 bytes to source/misc/reference_directions.ipynb
# [NbConvertApp] Converting notebook source/algorithms/usage.ipynb to notebook
# [NbConvertApp] Writing 15263 bytes to source/algorithms/usage.ipynb
# [NbConvertApp] Converting notebook source/algorithms/initialization.ipynb to notebook
# [NbConvertApp] Writing 1960 bytes to source/algorithms/initialization.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/ctaea.ipynb to notebook
# [NbConvertApp] Writing 175336 bytes to source/algorithms/moo/ctaea.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/rvea.ipynb to notebook
# [NbConvertApp] Writing 86222 bytes to source/algorithms/moo/rvea.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/moead.ipynb to notebook
# [NbConvertApp] Writing 78894 bytes to source/algorithms/moo/moead.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/nsga3.ipynb to notebook
# [NbConvertApp] Writing 145783 bytes to source/algorithms/moo/nsga3.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/.ipynb_checkpoints/nsga2-checkpoint.ipynb to notebook
# [NbConvertApp] Writing 41322 bytes to source/algorithms/moo/.ipynb_checkpoints/nsga2-checkpoint.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/age.ipynb to notebook
# [NbConvertApp] Writing 45630 bytes to source/algorithms/moo/age.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/dnsga2.ipynb to notebook
# [NbConvertApp] Writing 83578 bytes to source/algorithms/moo/dnsga2.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/rnsga3.ipynb to notebook
# [NbConvertApp] Writing 96565 bytes to source/algorithms/moo/rnsga3.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/unsga3.ipynb to notebook
# [NbConvertApp] Writing 28245 bytes to source/algorithms/moo/unsga3.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/sms.ipynb to notebook
# [NbConvertApp] Writing 19619 bytes to source/algorithms/moo/sms.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/nsga2.ipynb to notebook
# [NbConvertApp] Writing 41322 bytes to source/algorithms/moo/nsga2.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/age2.ipynb to notebook
# [NbConvertApp] Writing 28124 bytes to source/algorithms/moo/age2.ipynb
# [NbConvertApp] Converting notebook source/algorithms/moo/rnsga2.ipynb to notebook
# [NbConvertApp] Writing 17594 bytes to source/algorithms/moo/rnsga2.ipynb
# [NbConvertApp] Converting notebook source/algorithms/list.ipynb to notebook
# [NbConvertApp] Writing 1333 bytes to source/algorithms/list.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/sres.ipynb to notebook
# [NbConvertApp] Writing 4339 bytes to source/algorithms/soo/sres.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/isres.ipynb to notebook
# [NbConvertApp] Writing 3238 bytes to source/algorithms/soo/isres.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/es.ipynb to notebook
# [NbConvertApp] Writing 3559 bytes to source/algorithms/soo/es.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/pso.ipynb to notebook
# [NbConvertApp] Writing 5440 bytes to source/algorithms/soo/pso.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/de.ipynb to notebook
# [NbConvertApp] Writing 6765 bytes to source/algorithms/soo/de.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/nelder.ipynb to notebook
# [NbConvertApp] Writing 2576 bytes to source/algorithms/soo/nelder.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/brkga.ipynb to notebook
# [NbConvertApp] Writing 6718 bytes to source/algorithms/soo/brkga.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/pattern.ipynb to notebook
# [NbConvertApp] Writing 2630 bytes to source/algorithms/soo/pattern.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/g3pcx.ipynb to notebook
# [NbConvertApp] Writing 2516 bytes to source/algorithms/soo/g3pcx.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/ga.ipynb to notebook
# [NbConvertApp] Writing 4621 bytes to source/algorithms/soo/ga.ipynb
# [NbConvertApp] Converting notebook source/algorithms/soo/cmaes.ipynb to notebook
# [NbConvertApp] Writing 11796 bytes to source/algorithms/soo/cmaes.ipynb
# [NbConvertApp] Converting notebook source/algorithms/hyperparameters.ipynb to notebook
# [NbConvertApp] Writing 16008 bytes to source/algorithms/hyperparameters.ipynb
# [NbConvertApp] Converting notebook source/algorithms/index.ipynb to notebook
# [NbConvertApp] Writing 2702 bytes to source/algorithms/index.ipynb
# [NbConvertApp] Converting notebook source/faq.ipynb to notebook
# [NbConvertApp] Writing 1545 bytes to source/faq.ipynb
# DONE
